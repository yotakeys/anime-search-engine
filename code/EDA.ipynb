# %%
import pandas as pd

# %%
anime_data = pd.read_csv('../dataset/raw/animes.csv')
review_data = pd.read_csv('../dataset/raw/reviews.csv')

# %% [markdown]
# ### Anime exploratory

# %%
anime_data.sample(10)
# Out:
#          uid                               title  \
# 7382    5826                      Oira no Yakyuu
# 8090    8968                          Shogi Hour
# 16315  16059  Aku no Onna Kanbu: Full Moon Night
# 8580   30446                  Akazukin to Kenkou
# 4033   28959                    Kizuna (Special)
# 15882   2138                          Kage (OVA)
# 14233  37067                   Yume no Tochuu de
# 7326    4353     Gakuen Heaven: Hamu Hamu Heaven
# 12927  40393    Taka no Tsume-dan no Ike! ODAman
# 8279   21891                       Natsumi Step!
#
#                                                 synopsis  \
# 7382   Movie from 1931 about a baseball game between ...
# 8090   A NHK shogi tournament parody. ''55 AJN Trophy...
# 16315  Katsuma is just a go-boy of his female bosses....
# 8580   Graduation Work of Inoue Ryou which won the To...
# 4033                          Short animation by Tekken.
# 15882  It is the peaceful Edo period in Japan, and ni...
# 14233  A song about the softness you feel when you dr...
# 7326               Specials from the Gakuen Heaven DVDs.
# 12927  A collaboration between the  Eagle Talon  fran...
# 8279   A story about an adorable girl who travels to ...
#
#                                                    genre  \
# 7382                                          ['Sports']
# 8090                        ['Parody', 'Game', 'Comedy']
# 16315                         ['Hentai', 'Supernatural']
# 8580                                          ['Comedy']
# 4033               ['Slice of Life', 'Romance', 'Drama']
# 15882  ['Action', 'Martial Arts', 'Hentai', 'Historic...
# 14233                                  ['Kids', 'Music']
# 7326   ['Comedy', 'Drama', 'Romance', 'School', 'Shou...
# 12927                          ['Parody', 'Super Power']
# 8279                                           ['Music']
#
#                               aired  episodes  members  popularity   ranked  \
# 7382                      Mar, 1931       1.0     1365        8854  10229.0
# 8090                    Oct 5, 2008       1.0      667       10351  10901.0
# 16315                  Dec 21, 2012       1.0     6891        5061      NaN
# 8580                           2007       1.0      272       12449  10422.0
# 4033                           2012       1.0      672       10343   9184.0
# 15882  Mar 26, 2004 to Dec 26, 2004       4.0     4717        5886      NaN
# 14233                     Aug, 2017       1.0       90       15531  14588.0
# 7326     Jul 7, 2006 to Dec 8, 2006      12.0     6150        5297   4590.0
# 12927             Sep 20, 2018 to ?       NaN       83       15674  14114.0
# 8279                           2003       1.0      248       12715  10717.0
#
#        score                                            img_url  \
# 7382    5.38  https://cdn.myanimelist.net/images/anime/7/122...
# 8090    4.99  https://cdn.myanimelist.net/images/anime/4/248...
# 16315   6.83  https://cdn.myanimelist.net/images/anime/1716/...
# 8580    5.28  https://cdn.myanimelist.net/images/anime/6/728...
# 4033    5.74  https://cdn.myanimelist.net/images/anime/13/70...
# 15882   6.40  https://cdn.myanimelist.net/images/anime/1/227...
# 14233   5.46  https://cdn.myanimelist.net/images/anime/7/899...
# 7326    6.80  https://cdn.myanimelist.net/images/anime/6/841...
# 12927   7.00  https://cdn.myanimelist.net/images/anime/1318/...
# 8279    5.13  https://cdn.myanimelist.net/images/anime/8/578...
#
#                                                     link
# 7382   https://myanimelist.net/anime/5826/Oira_no_Yakyuu
# 8090       https://myanimelist.net/anime/8968/Shogi_Hour
# 16315  https://myanimelist.net/anime/16059/Aku_no_Onn...
# 8580   https://myanimelist.net/anime/30446/Akazukin_t...
# 4033   https://myanimelist.net/anime/28959/Kizuna_Spe...
# 15882        https://myanimelist.net/anime/2138/Kage_OVA
# 14233  https://myanimelist.net/anime/37067/Yume_no_To...
# 7326   https://myanimelist.net/anime/4353/Gakuen_Heav...
# 12927  https://myanimelist.net/anime/40393/Taka_no_Ts...
# 8279    https://myanimelist.net/anime/21891/Natsumi_Step

# %%
anime_data.describe()
# Out:
#                 uid      episodes       members    popularity        ranked  \
# count  19311.000000  18605.000000  1.931100e+04  19311.000000  16099.000000
# mean   19358.904096     11.460414  3.472609e+04   7720.830304   6866.524194
# std    14271.446515     47.950386  1.121772e+05   4676.786104   4390.018768
# min        1.000000      1.000000  2.500000e+01      1.000000      1.000000
# 25%     4833.500000      1.000000  3.880000e+02   3725.000000   2895.500000
# 50%    18327.000000      2.000000  2.389000e+03   7539.000000   6963.000000
# 75%    33896.500000     12.000000  1.450150e+04  11613.000000  10601.500000
# max    40960.000000   3057.000000  1.871043e+06  16338.000000  14675.000000
#
#               score
# count  18732.000000
# mean       6.436107
# std        1.007941
# min        1.250000
# 25%        5.770000
# 50%        6.410000
# 75%        7.150000
# max        9.230000

# %%
anime_data.describe(include='O')
# Out:
#                                            title  \
# count                                      19311
# unique                                     16214
# top     Hakkenden: Touhou Hakken Ibun 2nd Season
# freq                                           3
#
#                                                  synopsis       genre  \
# count                                               18336       19311
# unique                                              15194        4851
# top     No synopsis has been added for this series yet...  ['Hentai']
# freq                                                   46        1837
#
#                 aired                                            img_url  \
# count           19311                                              19131
# unique          11127                                              16051
# top     Not available  https://cdn.myanimelist.net/images/anime/1071/...
# freq              372                                                  3
#
#                                                      link
# count                                               19311
# unique                                              16216
# top     https://myanimelist.net/anime/18055/Hakkenden_...
# freq                                                    3

# %%
anime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19311 entries, 0 to 19310
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uid         19311 non-null  int64
#  1   title       19311 non-null  object
#  2   synopsis    18336 non-null  object
#  3   genre       19311 non-null  object
#  4   aired       19311 non-null  object
#  5   episodes    18605 non-null  float64
#  6   members     19311 non-null  int64
#  7   popularity  19311 non-null  int64
#  8   ranked      16099 non-null  float64
#  9   score       18732 non-null  float64
#  10  img_url     19131 non-null  object
#  11  link        19311 non-null  object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Reviews exploratory

# %%
review_data.sample(10)
# Out:
#            uid         profile  anime_uid  \
# 118780   40483         pursoul       1581
# 17772     1209         Yandere         47
# 37058   240279        EdSparta      32281
# 106651  250785           Zecis      32262
# 35667   257133       Falco2424        820
# 157762  208592         Corocis      28155
# 125998  246916   Arachnophobic      34494
# 26193   191490      Suzukaze15      28701
# 56122   185350  literaturenerd       8795
# 54636   262777         Bexx02k         60
#
#                                                      text  score  \
# 118780  \n           \n         \n           \n       ...      8
# 17772   \n           \n         \n           \n       ...      9
# 37058   \n           \n         \n           \n       ...     10
# 106651  \n           \n         \n           \n       ...      8
# 35667   \n           \n         \n           \n       ...      9
# 157762  \n           \n         \n           \n       ...      7
# 125998  \n           \n         \n           \n       ...      8
# 26193   \n           \n         \n           \n       ...      9
# 56122   \n           \n         \n           \n       ...      3
# 54636   \n           \n         \n           \n       ...     10
#
#                                                    scores  \
# 118780  {'Overall': '8', 'Story': '8', 'Animation': '8...
# 17772   {'Overall': '9', 'Story': '10', 'Animation': '...
# 37058   {'Overall': '10', 'Story': '10', 'Animation': ...
# 106651  {'Overall': '8', 'Story': '7', 'Animation': '8...
# 35667   {'Overall': '9', 'Story': '9', 'Animation': '4...
# 157762  {'Overall': '7', 'Story': '6', 'Animation': '9...
# 125998  {'Overall': '8', 'Story': '7', 'Animation': '8...
# 26193   {'Overall': '9', 'Story': '9', 'Animation': '1...
# 56122   {'Overall': '3', 'Story': '3', 'Animation': '3...
# 54636   {'Overall': '10', 'Story': '9', 'Animation': '...
#
#                                                  link
# 118780   https://myanimelist.net/reviews.php?id=40483
# 17772     https://myanimelist.net/reviews.php?id=1209
# 37058   https://myanimelist.net/reviews.php?id=240279
# 106651  https://myanimelist.net/reviews.php?id=250785
# 35667   https://myanimelist.net/reviews.php?id=257133
# 157762  https://myanimelist.net/reviews.php?id=208592
# 125998  https://myanimelist.net/reviews.php?id=246916
# 26193   https://myanimelist.net/reviews.php?id=191490
# 56122   https://myanimelist.net/reviews.php?id=185350
# 54636   https://myanimelist.net/reviews.php?id=262777

# %%
review_data.describe()
# Out:
#                  uid      anime_uid          score
# count  192112.000000  192112.000000  192112.000000
# mean   187648.127525   15273.300283       7.570235
# std     98748.902397   13480.565379       2.255167
# min         1.000000       1.000000       0.000000
# 25%    101779.500000    2167.000000       6.000000
# 50%    210913.500000   10793.000000       8.000000
# 75%    270383.000000   30205.000000       9.000000
# max    325747.000000   40807.000000      11.000000

# %%
review_data.describe(include='O')
# Out:
#              profile                                               text  \
# count         192112                                             192112
# unique         47885                                             130440
# top     Sidewinder51  \n           \n         \n           \n       ...
# freq             762                                                  8
#
#                                                    scores  \
# count                                              192112
# unique                                              29837
# top     {'Overall': '10', 'Story': '10', 'Animation': ...
# freq                                                13900
#
#                                                  link
# count                                          192112
# unique                                         130519
# top     https://myanimelist.net/reviews.php?id=321183
# freq                                                4

# %%
review_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192112 entries, 0 to 192111
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   uid        192112 non-null  int64
#  1   profile    192112 non-null  object
#  2   anime_uid  192112 non-null  int64
#  3   text       192112 non-null  object
#  4   score      192112 non-null  int64
#  5   scores     192112 non-null  object
#  6   link       192112 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 10.3+ MB

# %%
review_data['text'].iloc[1]
# Out:
# "\n           \n         \n           \n             \n           \n         \n         \n           more pics \n         \n       \n         \n       \n         \n           Overall \n           10 \n         \n         \n           Story \n           10 \n         \n                   \n             Animation \n             10 \n           \n           \n             Sound \n             10 \n           \n                 \n           Character \n           10 \n         \n         \n           Enjoyment \n           10 \n         \n       \n     \n\n                    \n    Let me start off by saying that Made in Abyss is a series that deserves to be bestowed with the title of a Masterpiece of an anime series. This may sound like I'm placing the series on a pedestal, and you could say that personal bias has influenced by decision to rate MIA a full 10/10 for all the components, but please allow me to try my best to break down and pinpoint just exactly why it has earned such a place in my heart.  \r\n \r\nBeginning with the first episode, which took me by serious surprise when I was left in absolute awe by the mystical vibes exuded by the astounding visuals and the beautiful soundtrack. MIA has one of the best first episodes I have ever seen thus far because unlike other shows where they bombard the audience with a complex plot in a desperate attempt to bait them into watching the rest of the show, MIA does that exact opposite. Instead, we tag along with our protagonist, Riko, and her adventures down into the abyss. Some things occur, and right off the bat, episode one was sufficient to leave me tense at the edge of my seat, yet the premise is simple and digestible enough for me to follow along. And at the end, we are treated with a stunning picturesque overview of the abyss, and that alone was enough to leave me desiring to be transported into their world and explore the abyss along with Riko. They had successfully pulled off their intended effect – to reproduce that sort of charm and mystery of the abyss, something that is so dangerous, slightly sinister, yet people, both the characters in MIA, along with the audience, are drawn to it.  \r\n \r\nMoving on to the crux of MIA, the plot. The first few episodes mask the true sinister reality of the show and I was tricked into thinking this would be a cute adventure series with Riko and friends, but boy does that completely change in the next few episodes to come. Now don’t get me wrong, being ‘dark’ or ‘deep’ doesn’t necessarily equate to a good compelling story, as plenty of shows that seek to achieve such an effect often go beyond their capacity and all that remains is simply a cringefest of wasted potential. Yet, MIA absolutely nails in its execution. Even in earlier parts where there was a lighter more upbeat tone, the story never got stale and it was just downright entertaining to witness the happenings and adventures of Riko and those around her. And now that I think about it, it wasn’t really the plot itself that was unique or fantastic, rather, it's the perfect pacing and storytelling the series chose to adopt that really sold the show to me. I would go so far as to say that MIA is somewhat like a deconstruction of adventure genres and how behind the excitement and thrill of going on a journey of never return, lies the harsh brutal reality, something that even 12 years olds are not immune to, and are in fact more prone to its effects due to their fragility.  \r\n \r\nI could not have asked for a better two main characters, Riko and Reg. One is an enthusiastic fearless adventurer and the other a shy yet fiercely protective friend. This iconic pair are extremely well written characters that spoke out to me on a profound level, weaving my emotional attachment towards them, and thus cue the tears and heartache when misfortune befell them. The complement and supplement each other in so many ways that it is just really darn endearing to see them interact. And due to spoiler ...
